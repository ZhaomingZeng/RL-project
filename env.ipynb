# %%
import gymnasium as gym
import numpy as np
from gym.spaces import Discrete, Box
import pygame


import os
import sys
import traci
import traci.constants as tc

if 'SUMO_HOME' in os.environ:
    sys.path.append(os.path.join(os.environ['SUMO_HOME'], 'tools'))
import traci

#load sumo configuration
sumoBinary = "sumo"
sumoCmd = [sumoBinary, "-c", "002.sumocfg"]

# %%
class Bus_holding_env(gym.Env):
    def __init__(self, render_mode=None, sumocfg="002.sumocfg"):
        self.bus = {0:'t_0',
                    1:'t_1',
                    2:'t_2',
                    3:'t_3'}
        self.busstop = {0:'bs_1',
                        1:'bs_2',
                        2:'bs_3',
                        3:'bs_4'}
        self.Compliane_score={0:1,
                              1:2/3,
                              2:1
        }
        self.loop = {0:'loop_1',
                        1:'loop_2',
                        2:'loop_3',
                        3:'loop_4'}
        self.control_busstop={0:'bs_1',
                                1:'bs_3'}
        self.control_bustop_index_convert ={0:0,
                                            1:2}
        
        self.control_bus={0:'t_1',
                        1:'t_2',
                        2:'t_3'}
        
        self.control_bus_index_convert ={0:1,
                                            1:2,
                                            2:3}

        self.observe_busstop=[1,2,3] 
        
        n,m=len(self.bus), len(self.busstop)
        
        self.max_headway=50
        self.initial_headway=20
        
        self.time_slice=15
        self.max_timesetp=400

        self.control_busstop_duration=20


        # self.action_space = gym.spaces.Discrete(6) # duration of holding of bus1, bus2,bus3
        self.action_space = gym.spaces.Discrete(20)
        

        self.observation_space=gym.spaces.Dict(
            {
                "headway": gym.spaces.Box(0, high=self.max_headway,  shape=(n, m), dtype=int),
                "target": gym.spaces.MultiDiscrete([3,2])
            }
        )
        self.decision_finish= np.full((len(self.control_bus),len(self.control_busstop)), False, dtype=bool)


        self.render_mode = render_mode

        #arrival time
        self.arrival_times = np.ones((n,m))*np.nan
        self.arrival_check = np.full((n,m), False, dtype=bool)

        #headway of bus [1,2,3] at bus_stop[1,2,3,4]
        self.headway = np.ones((n,m))*self.max_headway
        self.headway[0]=self.initial_headway

        #target=[target bus , target bus stop]
        self.target=np.array([0,0])


        #sumo start to simulate 
        self.sumocfg=sumocfg
        self.sumoCmd=["sumo", "-c",self.sumocfg]#, "--no-warnings" 

        traci.start(self.sumoCmd)
        print("check first start")



    def render(self):
        return None
    
    def reset(self, seed=42):

        traci.close()
        print("check reset close")
        traci.start(self.sumoCmd)
        print("check second start")


        # traci.start(self.sumoCmd)

        """
        sumo simulation run until the second bus reach the first control stop 
        update the arrival statue
        """
        found_ind=False
        while not found_ind :
            traci.simulationStep()

            #check arrival time of first two bus at first bus stop
            for bus_i in [0,1]:
                for busstop_j in [0]:
                    # check if not arrival 
                    if not self.arrival_check[bus_i][busstop_j]:
                        #check if bus_i arrive bus_j
                        loop_data=traci.inductionloop.getVehicleData(loopID=self.loop[busstop_j])
                        if loop_data!=[]:
                            if self.bus[bus_i] in loop_data[0][0]:
                                self.arrival_times[bus_i][busstop_j]=int(loop_data[0][2])# record the arrival time
                                self.arrival_check[bus_i][busstop_j]=True #update the arrival status

            if self.arrival_check[1][0] :
                found_ind=True
        
        self.target=np.array([0,0]) # the  holding decision should made on the bus[1] at stop[1]

        #update headway
        self.update_headway()
        
        observation = self._get_obs()
        info = {}

        return observation,info

    def step(self, action):
        # action is duration of holding
        stop_duration=10+ 3* action* self.Compliane_score[self.target[0]]
        traci.vehicle.setBusStop(vehID=self.control_bus[self.target[0]]
                                 ,stopID=self.control_busstop[self.target[1]]
                                 , duration=stop_duration)
        
        #update finished decision 
        self.decision_finish[self.target[0], self.target[1]]=True

        if self.decision_finish[-1][-1]: #last decision is finished
            terminated = True

        else:
            terminated = False
        
        
        # if not terminate find the next decision step 
        if not terminated:
            next_decision_found=False
            while not next_decision_found:
                traci.simulationStep()
                self.arrival_update()
                for row in np.argwhere(self.decision_finish==False):
                    i=self.control_bus_index_convert[row[0]]
                    j=self.control_bustop_index_convert[row[1]]
                    if self.arrival_check[i,j]==True:
                        self.target=row
                        self.update_headway()
                        next_decision_found=True


        observation=self._get_obs()


        #reward:
        if terminated:
            # simulate until last bus arrive last stop 
            while not np.all(self.arrival_check):
                traci.simulationStep()
                self.arrival_update()
        
            # calculate the headway 
            E_h= np.mean(self.headway, axis=0)
            Var_h=np.var(self.headway, axis=0)
            reward = - sum([ E_h[j]/2*(1+Var_h[j]/E_h[j]**2) for j in range(len(E_h))]) - action
            

        else:
            reward=-action


        info={}

        return observation, reward, terminated, False, info

        
    def sumo_finish(self):
        """check if sumo terminate, which means no vehicle left in the network"""
        end = True if traci.simulation.getMinExpectedNumber()==0 else False
        return end

    
    def update_headway(self):
        previous_arrivals = np.roll(self.arrival_times , shift=1, axis=0)
        valid = ~np.isnan(self.arrival_times) & ~np.isnan(self.arrival_times)
        self.headway[1:, :] = np.where(valid[1:, :], self.arrival_times[1:, :] - previous_arrivals[1:, :], 50)


    def _get_obs(self):
        headway = self.headway
        target = self.target  # target bus, and stop 
        obs= {"headway":headway,
              "target":target}
        return obs
    
    def arrival_update(self):
        """record/ update each vehicle arrive stop time"""
        #get each vehicle first unarrival stop 
        for i in range(self.arrival_check.shape[0]):
            unarriaval_bs = np.argwhere( self.arrival_check[i]==False).tolist()
            if unarriaval_bs!=[]:
                bus_stop=unarriaval_bs[0][0]
                loop_data=traci.inductionloop.getVehicleData(loopID=self.loop[bus_stop]) # The first unarrival stop for bus i
                if loop_data!=[]:
                    if self.bus[i] in loop_data[0][0]:
                        self.arrival_times[i][bus_stop]=int(loop_data[0][2])# record the arrival time
                        self.arrival_check[i][bus_stop]=True #update the arrival status
                

    def close(self):
        traci.close()

# %%
env=Bus_holding_env()
env.reset()
# Out:
#  Retrying in 1 seconds
# check first start
# Step #0.00 (0ms ?*RT. ?UPS, TraCI: 1ms, vehicles TOT 0 ACT 0 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ({'headway': array([[20., 20., 20., 20.],
#          [22., 50., 50., 50.],
#          [50., 50., 50., 50.],
#          [50., 50., 50., 50.]]),
#   'target': array([0, 0])},
#  {})

# %%
env.close()
# Out:
# Step #78.00 (0ms ?*RT. ?UPS, TraCI: 3900ms, vehicles TOT 2 ACT 2 BUF 0)

# %%
import gymnasium as gym

from stable_baselines3 import DQN

env = Bus_holding_env()

model = DQN("MultiInputPolicy", env, verbose=1)
model.learn(total_timesteps=10000, log_interval=4)
model.save("dqn_bus_holding")
# Out:
#  Retrying in 1 seconds
# check first start
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Step #0.00 (0ms ?*RT. ?UPS, TraCI: 44ms, vehicles TOT 0 ACT 0 BUF 0)
# check reset close
#  Retrying in 1 seconds
# /opt/miniconda3/envs/py38/lib/python3.8/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:77: UserWarning: The `render_mode` attribute is not defined in your environment. It will be set to None.
#   warnings.warn("The `render_mode` attribute is not defined in your environment. It will be set to None.")
# check second start
# Step #364.00 (0ms ?*RT. ?UPS, TraCI: 1ms, vehicles TOT 4 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.25     |
# |    ep_rew_mean      | -121     |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1        |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 9        |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.62     |
# |    ep_rew_mean      | -114     |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1        |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 13       |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.42     |
# |    ep_rew_mean      | -111     |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1        |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 17       |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (1ms ~= 1000.00*RT, ~1000.00UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.31     |
# |    ep_rew_mean      | -110     |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1        |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 21       |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.25     |
# |    ep_rew_mean      | -110     |
# |    exploration_rate | 0.976    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1        |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 25       |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.21     |
# |    ep_rew_mean      | -109     |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1        |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 29       |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (1ms ~= 1000.00*RT, ~1000.00UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.18     |
# |    ep_rew_mean      | -109     |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1        |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 33       |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 6ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.16     |
# |    ep_rew_mean      | -109     |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1        |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 37       |
# ----------------------------------
# Step #1.00 (1ms ~= 1000.00*RT, ~1000.00UPS, TraCI: 19ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (1ms ~= 1000.00*RT, ~1000.00UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.14     |
# |    ep_rew_mean      | -109     |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1        |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 41       |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 5ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 10ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.12     |
# |    ep_rew_mean      | -109     |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 0        |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 45       |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 5ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.11     |
# |    ep_rew_mean      | -108     |
# |    exploration_rate | 0.953    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 0        |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 49       |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.1      |
# |    ep_rew_mean      | -108     |
# |    exploration_rate | 0.95     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 0        |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 53       |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.1      |
# |    ep_rew_mean      | -108     |
# |    exploration_rate | 0.946    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 0        |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 57       |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (1ms ~= 1000.00*RT, ~1000.00UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.09     |
# |    ep_rew_mean      | -108     |
# |    exploration_rate | 0.942    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 0        |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 61       |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.08     |
# |    ep_rew_mean      | -108     |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 0        |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 65       |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.08     |
# |    ep_rew_mean      | -108     |
# |    exploration_rate | 0.934    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 0        |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 69       |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.07     |
# |    ep_rew_mean      | -108     |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 0        |
# |    time_elapsed     | 75       |
# |    total_timesteps  | 73       |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.07     |
# |    ep_rew_mean      | -108     |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 0        |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 77       |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.07     |
# |    ep_rew_mean      | -108     |
# |    exploration_rate | 0.923    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 0        |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 81       |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | -108     |
# |    exploration_rate | 0.919    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 0        |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 85       |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (1ms ~= 1000.00*RT, ~1000.00UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 7ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | -108     |
# |    exploration_rate | 0.915    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 0        |
# |    time_elapsed     | 93       |
# |    total_timesteps  | 89       |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | -108     |
# |    exploration_rate | 0.912    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 0        |
# |    time_elapsed     | 97       |
# |    total_timesteps  | 93       |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | -108     |
# |    exploration_rate | 0.908    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 0        |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 97       |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | -108     |
# |    exploration_rate | 0.904    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 0        |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 101      |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 15ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | -108     |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 0        |
# |    time_elapsed     | 110      |
# |    total_timesteps  | 105      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 103      |
# |    n_updates        | 1        |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 5ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 5ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 8ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -107     |
# |    exploration_rate | 0.896    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 0        |
# |    time_elapsed     | 115      |
# |    total_timesteps  | 109      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 91.5     |
# |    n_updates        | 2        |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (1ms ~= 1000.00*RT, ~1000.00UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 8ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -107     |
# |    exploration_rate | 0.893    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 0        |
# |    time_elapsed     | 119      |
# |    total_timesteps  | 113      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 105      |
# |    n_updates        | 3        |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (1ms ~= 1000.00*RT, ~1000.00UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 9ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -107     |
# |    exploration_rate | 0.889    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 0        |
# |    time_elapsed     | 123      |
# |    total_timesteps  | 117      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 103      |
# |    n_updates        | 4        |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 11ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -107     |
# |    exploration_rate | 0.885    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 0        |
# |    time_elapsed     | 128      |
# |    total_timesteps  | 121      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 104      |
# |    n_updates        | 5        |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (1ms ~= 1000.00*RT, ~1000.00UPS, TraCI: 9ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -107     |
# |    exploration_rate | 0.881    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 0        |
# |    time_elapsed     | 132      |
# |    total_timesteps  | 125      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 102      |
# |    n_updates        | 6        |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 5ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 10ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -107     |
# |    exploration_rate | 0.877    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 0        |
# |    time_elapsed     | 137      |
# |    total_timesteps  | 129      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 107      |
# |    n_updates        | 7        |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (1ms ~= 1000.00*RT, ~1000.00UPS, TraCI: 12ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -107     |
# |    exploration_rate | 0.874    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 0        |
# |    time_elapsed     | 141      |
# |    total_timesteps  | 133      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 99.9     |
# |    n_updates        | 8        |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 8ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -106     |
# |    exploration_rate | 0.87     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 0        |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 137      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 101      |
# |    n_updates        | 9        |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 9ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -106     |
# |    exploration_rate | 0.866    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 0        |
# |    time_elapsed     | 150      |
# |    total_timesteps  | 141      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 100      |
# |    n_updates        | 10       |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (1ms ~= 1000.00*RT, ~1000.00UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 9ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -106     |
# |    exploration_rate | 0.862    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 0        |
# |    time_elapsed     | 154      |
# |    total_timesteps  | 145      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 108      |
# |    n_updates        | 11       |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 5ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 8ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -106     |
# |    exploration_rate | 0.858    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 0        |
# |    time_elapsed     | 159      |
# |    total_timesteps  | 149      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 102      |
# |    n_updates        | 12       |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 11ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -107     |
# |    exploration_rate | 0.855    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 0        |
# |    time_elapsed     | 163      |
# |    total_timesteps  | 153      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 93.3     |
# |    n_updates        | 13       |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 9ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -107     |
# |    exploration_rate | 0.851    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 0        |
# |    time_elapsed     | 167      |
# |    total_timesteps  | 157      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 97.7     |
# |    n_updates        | 14       |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -107     |
# |    exploration_rate | 0.847    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 0        |
# |    time_elapsed     | 172      |
# |    total_timesteps  | 161      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 103      |
# |    n_updates        | 15       |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 11ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -107     |
# |    exploration_rate | 0.843    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 0        |
# |    time_elapsed     | 176      |
# |    total_timesteps  | 165      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 101      |
# |    n_updates        | 16       |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 7ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 20ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -107     |
# |    exploration_rate | 0.839    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 0        |
# |    time_elapsed     | 181      |
# |    total_timesteps  | 169      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 105      |
# |    n_updates        | 17       |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 10ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -107     |
# |    exploration_rate | 0.836    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 0        |
# |    time_elapsed     | 185      |
# |    total_timesteps  | 173      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 103      |
# |    n_updates        | 18       |
# ----------------------------------
# Step #1.00 (1ms ~= 1000.00*RT, ~1000.00UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 10ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -107     |
# |    exploration_rate | 0.832    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 0        |
# |    time_elapsed     | 189      |
# |    total_timesteps  | 177      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 102      |
# |    n_updates        | 19       |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 10ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -107     |
# |    exploration_rate | 0.828    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 0        |
# |    time_elapsed     | 194      |
# |    total_timesteps  | 181      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 92.9     |
# |    n_updates        | 20       |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 10ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -107     |
# |    exploration_rate | 0.824    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 0        |
# |    time_elapsed     | 198      |
# |    total_timesteps  | 185      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 99.9     |
# ...
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 8ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -97.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9940     |
# |    fps              | 0        |
# |    time_elapsed     | 13717    |
# |    total_timesteps  | 9945     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000823 |
# |    n_updates        | 2461     |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 5ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 9ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -97.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9944     |
# |    fps              | 0        |
# |    time_elapsed     | 13722    |
# |    total_timesteps  | 9949     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00413  |
# |    n_updates        | 2462     |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 5ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (1ms ~= 1000.00*RT, ~1000.00UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 10ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -97.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9948     |
# |    fps              | 0        |
# |    time_elapsed     | 13726    |
# |    total_timesteps  | 9953     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00385  |
# |    n_updates        | 2463     |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 6ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 10ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -97.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9952     |
# |    fps              | 0        |
# |    time_elapsed     | 13731    |
# |    total_timesteps  | 9957     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00279  |
# |    n_updates        | 2464     |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 5ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (1ms ~= 1000.00*RT, ~1000.00UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 11ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -97.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9956     |
# |    fps              | 0        |
# |    time_elapsed     | 13735    |
# |    total_timesteps  | 9961     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00116  |
# |    n_updates        | 2465     |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 5ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (1ms ~= 1000.00*RT, ~1000.00UPS, TraCI: 12ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -97.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9960     |
# |    fps              | 0        |
# |    time_elapsed     | 13740    |
# |    total_timesteps  | 9965     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0004   |
# |    n_updates        | 2466     |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 5ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -97.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9964     |
# |    fps              | 0        |
# |    time_elapsed     | 13744    |
# |    total_timesteps  | 9969     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00316  |
# |    n_updates        | 2467     |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 6ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 10ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -97.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9968     |
# |    fps              | 0        |
# |    time_elapsed     | 13748    |
# |    total_timesteps  | 9973     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00653  |
# |    n_updates        | 2468     |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 5ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (1ms ~= 1000.00*RT, ~1000.00UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 9ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -97.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9972     |
# |    fps              | 0        |
# |    time_elapsed     | 13753    |
# |    total_timesteps  | 9977     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00184  |
# |    n_updates        | 2469     |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 6ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 8ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -97.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9976     |
# |    fps              | 0        |
# |    time_elapsed     | 13757    |
# |    total_timesteps  | 9981     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00175  |
# |    n_updates        | 2470     |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 6ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 8ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 10ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -97.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9980     |
# |    fps              | 0        |
# |    time_elapsed     | 13762    |
# |    total_timesteps  | 9985     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00115  |
# |    n_updates        | 2471     |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 6ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 9ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -97.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9984     |
# |    fps              | 0        |
# |    time_elapsed     | 13766    |
# |    total_timesteps  | 9989     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.16     |
# |    n_updates        | 2472     |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 6ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -97.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9988     |
# |    fps              | 0        |
# |    time_elapsed     | 13770    |
# |    total_timesteps  | 9993     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0149   |
# |    n_updates        | 2473     |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 5ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (1ms ~= 1000.00*RT, ~1000.00UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -97.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9992     |
# |    fps              | 0        |
# |    time_elapsed     | 13775    |
# |    total_timesteps  | 9997     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0031   |
# |    n_updates        | 2474     |
# ----------------------------------
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 6ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start

# %%
env=Bus_holding_env()
# Out:
#  Retrying in 1 seconds
# check first start

# %%
#
del model # remove to demonstrate saving and loading

model = DQN.load("dqn_bus_holding")

obs, info = env.reset()
while True:
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    print(obs)
    print(action)
    if terminated or truncated:
        obs, info = env.reset()
# Out:
# Step #0.00 (0ms ?*RT. ?UPS, TraCI: 1718ms, vehicles TOT 0 ACT 0 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14., 50., 50.],
#        [57., 50., 50., 50.],
#        [50., 50., 50., 50.]]), 'target': array([1, 0])}
# 0
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14., 50., 50.],
#        [57., 50., 50., 50.],
#        [22., 50., 50., 50.]]), 'target': array([2, 0])}
# 0
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3., 50.],
#        [57., 66., 50., 50.],
#        [22., 50., 50., 50.]]), 'target': array([0, 1])}
# 0
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 50.],
#        [22., 14., 50., 50.]]), 'target': array([1, 1])}
# 0
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 50.],
#        [22., 14.,  3., 50.]]), 'target': array([2, 1])}
# 3
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 50.],
#        [22., 14.,  3., 50.]]), 'target': array([2, 1])}
# 3
# Step #316.00 (0ms ?*RT. ?UPS, TraCI: 1ms, vehicles TOT 4 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 5ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 5ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 5ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 7ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 5ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (1ms ~= 1000.00*RT, ~1000.00UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (1ms ~= 1000.00*RT, ~1000.00UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 5ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (1ms ~= 1000.00*RT, ~1000.00UPS, TraCI: 3ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# check second start
# {'headway': array([[20., 20., 20., 20.],
#        [22., 14.,  3.,  7.],
#        [57., 66., 79., 80.],
#        [22., 14.,  3., 16.]]), 'target': array([0, 0])}
# 0
# Step #1.00 (0ms ?*RT. ?UPS, TraCI: 4ms, vehicles TOT 1 ACT 1 BUF 0)
# check reset close
#  Retrying in 1 seconds
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File /opt/miniconda3/envs/py38/lib/python3.8/site-packages/traci/main.py:97, in connect(port, numRetries, host, proc, waitBetweenRetries, traceFile, traceGetters, label)
#      96 try:
# ---> 97     return connection.Connection(host, port, proc, traceFile, traceGetters, label)
#      98 except socket.error as e:
#
# File /opt/miniconda3/envs/py38/lib/python3.8/site-packages/traci/connection.py:83, in Connection.__init__(self, host, port, process, traceFile, traceGetters, label)
#      82 try:
# ---> 83     self._socket.connect((host, port))
#      84 except socket.error:
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[665], line 13
#      11 print(action)
#      12 if terminated or truncated:
# ---> 13     obs, info = env.reset()
#
# Cell In[656], line 88, in Bus_holding_env.reset(self, seed)
#      86 traci.close()
#      87 print("check reset close")
# ---> 88 traci.start(self.sumoCmd)
#      89 print("check second start")
#      92 # traci.start(self.sumoCmd)
#
# File /opt/miniconda3/envs/py38/lib/python3.8/site-packages/traci/main.py:147, in start(cmd, port, numRetries, label, verbose, traceFile, traceGetters, stdout, doSwitch)
#     145 sumoProcess = subprocess.Popen(cmd2, stdout=stdout)
#     146 try:
# --> 147     result = init(sumoPort, numRetries, "localhost", label, sumoProcess, doSwitch, traceFile, traceGetters)
#     148     if traceFile is not None:
#     149         connection.get(label).write("start", "%s, port=%s, label=%s" % (repr(cmd), repr(port), repr(label)))
#
# File /opt/miniconda3/envs/py38/lib/python3.8/site-packages/traci/main.py:116, in init(port, numRetries, host, label, proc, doSwitch, traceFile, traceGetters)
#     109 def init(port=8813, numRetries=tc.DEFAULT_NUM_RETRIES, host="localhost", label="default", proc=None, doSwitch=True,
#     110          traceFile=None, traceGetters=True):
#     111     """
#     112     Establish a connection to a TraCI-Server and store it under the given
#     113     label. This method is not thread-safe. It accesses the connection
#     114     pool concurrently.
#     115     """
# --> 116     con = connect(port, numRetries, host, proc, 1, traceFile, traceGetters, label)
#     117     if doSwitch:
#     118         switch(label)
#
# File /opt/miniconda3/envs/py38/lib/python3.8/site-packages/traci/main.py:105, in connect(port, numRetries, host, proc, waitBetweenRetries, traceFile, traceGetters, label)
#     103         if retry < numRetries + 1:
#     104             print(" Retrying in %s seconds" % waitBetweenRetries)
# --> 105             time.sleep(waitBetweenRetries)
#     106 raise FatalTraCIError("Could not connect in %s tries" % (numRetries + 1))
#
# KeyboardInterrupt:

# %%
for i in range(3):
    traci.simulationStep()
traci.vehicle.setBusStop(stopID="bs_1",vehID="t_1", duration=37)

# %%
time_step=0
while time_step<40:
    traci.simulationStep()
    print(traci.simulation.getTime(), traci.busstop.getVehicleIDs("bs_1"))
    time_step+=1
# Out:
# 82.0 ('t_1',)
# 83.0 ('t_1',)
# 84.0 ('t_1',)
# 85.0 ('t_1',)
# 86.0 ('t_1',)
# 87.0 ('t_1',)
# 88.0 ('t_1',)
# 89.0 ('t_1',)
# 90.0 ('t_1',)
# 91.0 ('t_1',)
# 92.0 ('t_1',)
# 93.0 ('t_1',)
# 94.0 ('t_1',)
# 95.0 ('t_1',)
# 96.0 ('t_1',)
# 97.0 ('t_1',)
# 98.0 ('t_1',)
# 99.0 ('t_1',)
# 100.0 ('t_1',)
# 101.0 ('t_1',)
# 102.0 ('t_1',)
# 103.0 ('t_1',)
# 104.0 ('t_1',)
# 105.0 ('t_1',)
# 106.0 ('t_1',)
# 107.0 ('t_1',)
# 108.0 ('t_1',)
# 109.0 ('t_1',)
# 110.0 ('t_1',)
# 111.0 ('t_1',)
# 112.0 ('t_1',)
# 113.0 ('t_1',)
# 114.0 ('t_1',)
# 115.0 ('t_1',)
# 116.0 ('t_1',)
# 117.0 ('t_1',)
# 118.0 ('t_1',)
# 119.0 ()
# 120.0 ()
# 121.0 ()

# %%
traci.start(sumoCmd) 

""" terminate critia"""
def finish():
    end= True if traci.simulation.getMinExpectedNumber()==0 else False
    return end

"""restart"""
def restart():
    traci.close()
    return None



while traci.simulation.getTime()<180 and not finish():
    traci.simulationStep()
    if len(traci.busstop.getVehicleIDs(target_stop))!=0:
        print(step, traci.busstop.getVehicleIDs(target_stop))
    if "t_0" in traci.busstop.getVehicleIDs("bs_1"):
        print("target bus at target stop, step=", traci.simulation.getTime())

        break

#traci.close()
# Out:
#  Retrying in 1 seconds
# target bus at target stop, step= 61.0
